# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from subprocess import check_output
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("dataset/Upperfinal.csv")
print(df.head())
print(df.tail())
# Out:
#          Date    LTP  % Change   High    Low   Open   Qty.  Turnover
# 0  2019/03/13  239.0     -2.05  248.0  237.0  244.0  70458   11950.0
# 1  2019/03/12  245.0      4.26  246.0  234.0  235.0  94823   34300.0
# 2  2019/03/11  235.0      2.17  238.0  228.0  232.0  73683  164500.0
# 3  2019/03/10  230.0      0.00  234.0  226.0  230.0  41255   11500.0
# 4  2019/03/07  230.0      1.77  231.0  225.0  228.0  47328   46000.0
#           Date    LTP  % Change   High    Low   Open   Qty.  Turnover
# 37  2019/01/17  311.0      9.89  311.0  283.0  283.0  57490   12440.0
# 38  2019/01/16  283.0      9.69  283.0  258.0  258.0   3690   14150.0
# 39  2019/01/15  258.0      9.79  258.0  235.0  235.0   3685   10320.0
# 40  2019/01/14  336.0     50.00  336.0  235.0  235.0  14295   13440.0
# 41  2019/01/13  224.0      0.00  224.0  224.0  224.0  51875    8960.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-6f6ab9a0afbe> in <module>
#       2 print(df.head())
#       3 print(df.tail())
# ----> 4 df = np.log(df)
#
# AttributeError: 'str' object has no attribute 'log'

# %%
# df.drop(["#"],axis=1,inplace=True)
# df.to_csv (r'dataset/Upperfinal.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# print(df.head())
# print(df)
print(df.shape)
print(df.columns)
# df.describe
# Out:
# (42, 8)
# Index(['Date', 'LTP', '% Change', 'High', 'Low', 'Open', 'Qty.', 'Turnover'], dtype='object')

# %%
df[['LTP']].plot()
plt.title("Upper")
plt.show()

# %%
# Comulative Return
dr = df.cumsum()
dr.plot()
plt.title('Upper Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Upper Cumulative Returns')

# %%
plt.figure(figsize=(10,10))
lag_plot(df['Open'], lag=3)
plt.title('Upper Autocorrelation plot')
# Out:
# Text(0.5, 1.0, 'Upper Autocorrelation plot')

# %% [markdown]
# ARIMA (AutoRegressive Integrated Moving Average) for Time Series Prediction

# %%
df['Date'][41]
# Out:
# '2019/01/13'

# %%
train_data, test_data = df[0:int(len(df)*0.8)], df[int(len(df)*0.8):]
plt.figure(figsize=(12,7))
plt.title('Upper Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(df['LTP'], 'blue', label='Training Data')
plt.plot(test_data['LTP'], 'green', label='Testing Data')
plt.xticks(np.arange(0,31,5), df['Date'][0:31:5])
plt.legend()

# %%
# def smape_kun(y_true, y_pred):
#     return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) + np.abs(y_true))))

# %%
train_ar = train_data['LTP'].values
test_ar = test_data['LTP'].values

# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
history = [x for x in train_ar]
# print(type(history))
predictions = list()
for t in range(len(test_ar)):
    model = ARIMA(history, order=(1,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast(1)
    yhat = output[0]
    predictions.append(yhat)
    obs = test_ar[t]
    history.append(obs)
#     print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = smape_kun(test_ar, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)


# model=ARIMA(history,order=(1,1,0))
# model_fit=model.fit(disp=0)
# output=model_fit.forecast(100)
# predicted =output[0]

# plt.plot(predicted)
# Out:
# Testing Mean Squared Error: 2000.649
# Symmetric mean absolute percentage error: 10.516

# %%
plt.figure(figsize=(12,7))
plt.plot(df['LTP'], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['LTP'], color='red', label='Actual Price')
plt.title('Upper Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.xticks(np.arange(0,31,5), df['Date'][0:31:3])
plt.legend()

# %%
# test_data['Date'][0:31:10]
# Out:
# 33    2019/01/23
# Name: Date, dtype: object

# %%
plt.figure(figsize=(12,7))
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['LTP'], color='red', label='Actual Price')
plt.xticks(np.arange(0,25, 6), df['Date'][25:42:6])
plt.title('Upper Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
