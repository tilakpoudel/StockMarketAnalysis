# 25  2019/02/04  246.0     -2.77  253.0  245.0  251.0   95240     12300.0
# 26  2019/02/03  253.0     -1.94  258.0  251.0  258.0   99156     10120.0
# 27  2019/01/31  258.0      0.78  260.0  253.0  256.0   57691     10320.0
# 28  2019/01/30  256.0     -1.54  260.0  256.0  260.0   53226     12800.0
# 29  2019/01/29  260.0     -2.62  267.0  258.0  267.0   95372     13000.0
# 30  2019/01/28  267.0      0.00  270.0  266.0  267.0   64493     13350.0
# 31  2019/01/27  267.0     -2.55  279.0  261.0  274.0  121117     13350.0
# 32  2019/01/24  274.0     -1.44  285.0  270.0  278.0  122167  33758245.0
# 33  2019/01/23  278.0      6.92  286.0  255.0  260.0  138867     13900.0
# 34  2019/01/22  260.0     -1.14  266.0  237.0  263.0  217131     13000.0
# 35  2019/01/21  263.0     -9.93  292.0  263.0  292.0  403770      5260.0
# 36  2019/01/20  292.0     -6.11  342.0  280.0  326.0  729258     14600.0
# 37  2019/01/17  311.0      9.89  311.0  283.0  283.0   57490     12440.0
# 38  2019/01/16  283.0      9.69  283.0  258.0  258.0    3690     14150.0
# 39  2019/01/15  258.0      9.79  258.0  235.0  235.0    3685     10320.0
# 40  2019/01/14  336.0     50.00  336.0  235.0  235.0   14295     13440.0
# 41  2019/01/13  224.0      0.00  224.0  224.0  224.0   51875      8960.0
# (42, 8)
# Index(['Date', 'LTP', '% Change', 'High', 'Low', 'Open', 'Qty.', 'Turnover'], dtype='object')

# %%
df[['Low']].plot()
plt.title("Upper")
plt.show()

# %%
# Comulative Return
dr = df.cumsum()
dr.plot()
plt.title('Upper Cumulative Returns')
# Out:
# Text(0.5, 1.0, 'Upper Cumulative Returns')

# %%
plt.figure(figsize=(10,10))
lag_plot(df['Open'], lag=5)
plt.title('Upper Autocorrelation plot')
# Out:
# Text(0.5, 1.0, 'Upper Autocorrelation plot')

# %% [markdown]
# ARIMA (AutoRegressive Integrated Moving Average) for Time Series Prediction

# %%
df['Date'][41]
# Out:
# '2019/01/13'

# %%
train_data, test_data = df[0:int(len(df)*0.8)], df[int(len(df)*0.8):]
plt.figure(figsize=(12,7))
plt.title('Upper Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(df['Open'], 'blue', label='Training Data')
plt.plot(test_data['Open'], 'green', label='Testing Data')
plt.xticks(np.arange(0,31,5), df['Date'][0:31:5])
plt.legend()

# %%
def smape_kun(y_true, y_pred):
    return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) + np.abs(y_true))))

# %%
train_ar = train_data['Open'].values
test_ar = test_data['Open'].values

# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
history = [x for x in train_ar]
print(type(history))
predictions = list()
for t in range(len(test_ar)):
    model = ARIMA(history, order=(1,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_ar[t]
    history.append(obs)
#     print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = smape_kun(test_ar, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)
# Out:
# <class 'list'>
# Testing Mean Squared Error: 876.130
# Symmetric mean absolute percentage error: 13.075

# %%
plt.figure(figsize=(12,7))
plt.plot(df['Open'], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['Open'], color='red', label='Actual Price')
plt.title('Upper Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.xticks(np.arange(0,31,5), df['Date'][0:31:3])
plt.legend()

# %%
# test_data['Date'][0:31:10]
# Out:
# 33    2019/01/23
# Name: Date, dtype: object

# %%
plt.figure(figsize=(12,7))
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['Open'], color='red', label='Actual Price')
plt.xticks(np.arange(0,25, 6), df['Date'][25:42:6])
plt.title('Upper Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
